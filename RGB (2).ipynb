# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import cv2
 
img = cv2.imread('/content/drive/MyDrive/Colab Notebooks/frame1019.jpg', cv2.IMREAD_UNCHANGED)
 
print('Original Dimensions : ',img.shape)
 
scale_percent = 220 # percent of original size
width = 224
height = 224
dim = (width, height)
  
# resize image
resized = cv2.resize(img, dim, interpolation = cv2.INTER_AREA)
 
print('Resized Dimensions : ',resized.shape)
 
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# Original Dimensions :  (480, 640, 3)
# Resized Dimensions :  (224, 224, 3)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from skimage.io import imread, imshow

image = imread('/content/drive/MyDrive/Colab Notebooks/frame1019.jpg')
imshow(image)

# %%
resized.shape, resized
# Out:
# ((224, 224, 3), array([[[ 0,  0,  0],
#          [ 7,  7,  7],
#          [13, 13, 13],
#          ...,
#          [24, 30, 29],
#          [24, 30, 29],
#          [24, 30, 29]],
#
#         [[ 0,  0,  0],
#          [ 7,  7,  7],
#          [13, 13, 13],
#          ...,
#          [24, 30, 29],
#          [24, 30, 29],
#          [24, 30, 29]],
#
#         [[ 0,  0,  0],
#          [ 7,  7,  7],
#          [13, 13, 13],
#          ...,
#          [24, 30, 29],
#          [24, 30, 29],
#          [24, 30, 29]],
#
#         ...,
#
#         [[ 1,  1,  1],
#          [16, 14, 14],
#          [30, 28, 28],
#          ...,
#          [17, 23, 95],
#          [25, 30, 74],
#          [30, 38, 56]],
#
#         [[ 1,  1,  1],
#          [16, 14, 14],
#          [30, 28, 28],
#          ...,
#          [18, 23, 95],
#          [26, 30, 74],
#          [29, 39, 56]],
#
#         [[ 1,  1,  1],
#          [16, 14, 14],
#          [30, 28, 28],
#          ...,
#          [18, 23, 95],
# ...

# %%
print(resized)
# Out:
# [[[ 0  0  0]
#   [ 7  7  7]
#   [13 13 13]
#   ...
#   [24 30 29]
#   [24 30 29]
#   [24 30 29]]
#
#  [[ 0  0  0]
#   [ 7  7  7]
#   [13 13 13]
#   ...
#   [24 30 29]
#   [24 30 29]
#   [24 30 29]]
#
#  [[ 0  0  0]
#   [ 7  7  7]
#   [13 13 13]
#   ...
#   [24 30 29]
#   [24 30 29]
#   [24 30 29]]
#
#  ...
#
#  [[ 1  1  1]
#   [16 14 14]
#   [30 28 28]
#   ...
#   [17 23 95]
#   [25 30 74]
#   [30 38 56]]
#
#  [[ 1  1  1]
#   [16 14 14]
#   [30 28 28]
#   ...
#   [18 23 95]
#   [26 30 74]
#   [29 39 56]]
#
#  [[ 1  1  1]
#   [16 14 14]
#   [30 28 28]
#   ...
#   [18 23 95]
#   [26 30 74]
#   [29 39 56]]]

# %%
# !pip install xlsxwriter
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 149 kB 7.5 MB/s
# ...

# %%
import cv2
import numpy as np
import xlsxwriter
b, g, r = cv2.split(resized)

ttl = resized.size / 3 #divide by 3 to get the number of image PIXELS

"""b, g, and r are actually numpy.ndarray types,
so you need to use the appropriate method to sum
all array elements"""
B = float(np.sum(b)) / ttl #convert to float, as B, G, and R will otherwise be int
G = float(np.sum(g)) / ttl
R = float(np.sum(r)) / ttl
B_mean1 = list()
G_mean1 = list()
R_mean1 = list()
B_mean1.append(B)
G_mean1.append(G)
R_mean1.append(R)

# %%
B
# Out:
# 87.241279296875

# %%
B_mean1
# Out:
# [87.241279296875]

# %%
b
# Out:
# array([[ 0,  7, 13, ..., 24, 24, 24],
#        [ 0,  7, 13, ..., 24, 24, 24],
#        [ 0,  7, 13, ..., 24, 24, 24],
#        ...,
#        [ 1, 16, 30, ..., 17, 25, 30],
#        [ 1, 16, 30, ..., 18, 26, 29],
#        [ 1, 16, 30, ..., 18, 26, 29]], dtype=uint8)

# %%
import pandas as pd

array = b

df = pd.DataFrame(array).T
df.to_excel(excel_writer = "/content/drive/MyDrive/Digit/bbb1.xlsx")

# %%
import pandas as pd

array = g

df = pd.DataFrame(array).T
df.to_excel(excel_writer = "/content/drive/MyDrive/Digit/ggg2.xlsx")

# %%
import pandas as pd

array = r

df = pd.DataFrame(array).T
df.to_excel(excel_writer = "/content/drive/MyDrive/Digit/rrr3.xlsx")

# %%
RGB = imread('/content/drive/MyDrive/Frame/frame0.jpg') 
R = RGB(1) 
G = RGB(480 ,640 ,2) 
B = RGB(480 ,640 ,3) 
xlswrite('Red.xls', R)
xlswrite('Green.xls', G)
xlswrite('Blue.xls', B)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-3cc13c03fd7a> in <module>
#       1 RGB = imread('/content/drive/MyDrive/Frame/frame0.jpg')
# ----> 2 R = RGB(1)
#       3 G = RGB(480 ,640 ,2)
#       4 B = RGB(480 ,640 ,3)
#       5 xlswrite('Red.xls', R)
#
# TypeError: 'numpy.ndarray' object is not callable

# %%
import pandas as pd

array = image

df = pd.DataFrame(array).T
df.to_excel(excel_writer = "/content/drive/MyDrive/Digit/iamge.xlsx")

# %%
import cv2

import csv

import numpy as np

def pic_data_strip_csv(): 
  img = cv2.imread(r"/content/drive/MyDrive/Frame/frame0.jpg")
  img_height, img_width = img.shape[:2]
  for x in range (0, img_height,1):
    for y in range (0,img_width,1):
      pixel_value = img[x,y,:]
      with open(r"/content/drive/MyDrive/Digit/tes.csv",mode="a") as pic_data:
        pic_data_writer = csv.writer(pic_data, delimiter=",", quotechar='"', quoting=csv.QUOTE_MINIMAL)
        write_pic_data = pic_data_writer.writerow([x,y,pixel_value])
        return()

# %%
def pic_data_strip_dict_csv():

img = cv2.imread(r"image-path")

img_height, img_width = img.shape[:2]

with open(r"dict csv-file-path",mode="a",newline="") as pic_data:

field_names = ["x","y","bgr"]

pic_data_writer = csv.DictWriter(pic_data, fieldnames=field_names)

pic_data_writer.writeheader()

for x in range (0, img_height,1):

for y in range (0,img_width,1):

pixel_value = img[x,y,:]

write_pic_data = pic_data_writer.writerow({"x":x,"y":y,"bgr":pixel_value})

return()

'''Sudheer'''

def create_pic_from_csv():

image = np.zeros((512,512,3), np.uint8)

with open(r"dict csv-file-path", newline="") as csvfile:

reader = csv.DictReader(csvfile)

for row in reader:

x = row["x"]

x = int(x)

y = row["y"]

y = int(y)

bgr = row["bgr"]

#gets the BGR value out of the []

bgr_edit = str(bgr)

print(bgr_edit)

head,sep,tail = bgr_edit.partition(" ")

b = head.strip("[")

bgr_tail = tail.strip()

bgr_tail = bgr_tail.replace("]","")

head,sep,tail = bgr_tail.partition(" ")

g = head

r = tail

b = int(b)

g = int(g)

r = int(r)

image[x,y]=[b,g,r]

cv2.imshow("xkcd 1696",image)

cv2.waitKey(0)

cv2.destroyAllWindows()

return()

pic_data_strip_csv()

pic_data_strip_dict_csv()

create_pic_from_csv()
